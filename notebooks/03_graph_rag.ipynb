# %% [markdown]
# # Graph RAG
#
# extract entities → expand Neo4j subgraph → fetch chunks → generate

# %%
from dotenv import load_dotenv
load_dotenv()

from rag.registry import run

out = run('graph', 'What is LangGraph?')
print(out['answer'])

# %%
import json
print(json.dumps(out['trace'], indent=2, default=str))
